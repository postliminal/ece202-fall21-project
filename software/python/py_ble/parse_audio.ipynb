', '-12', '-29', '-33', '-35', '-37', '-35', '-32', '-28', '-28', '-30', '-35', '-38', '-12', '-12', '-13', '-9', '-3', '-8', '-7', '-7', '-8', '-6', '-10', '-21', '-21', '-23', '-26', '-21', '-13', '-10', '-4', '-3', '-4', '-9', '-9', '-10', '-18', '-13', '-6', '-10', '-15', '-32', '-30', '-26', '-22', '-21', '-22', '-27', '-30', '-29', '-24', '-22', '-24', '-21', '-29', '-31', '-30', '-28', '-29', '-26', '-22', '-27', '-30', '-8', '-4', '-4', '-13', '-19', '-19', '-19', '-22', '-21', '-13', '-18', '3', '8', '6', '5', '3', '2', '2', '3', '4', '9', '6', '2', '5', '6', '11', '7', '11', '20', '17', '17', '17', '17', '20', '21', '22', '23', '23', '22', '20', '20', '22', '20', '16', '30', '28', '28', '28', '27', '29', '31', '30', '31', '30', '30', '31', '31', '34', '31', '27', '28', '16', '17', '17', '13', '7', '7', '7', '2', '-3', '-4', '-3', '-2', '1', '2', '1', '-22', '-21', '-21', '-22', '-21', '-22', '-24', '-24', '-23', '-24', '-22', '-17', '-15', '-14', '-12', '-12', '-13', '-10', '-10', '-11 ...

# %%
# 16khz sampling rate
#data is in int16
npdata = numpy.array(dum)
npdata = npdata.astype(numpy.int16)
print(type(npdata[0]))
# Out:
# <class 'numpy.int16'>

# %%
wavfile.write(outfile, 16000, npdata)

# %%
print("max: {}".format(max(npdata) ))
print("min: {}".format(min(npdata) ))
print("len: {}".format(len(npdata) ))
# Out:
# max: 62
# min: -67
# len: 15999

# %%
import matplotlib.pyplot as plt
plt.figure(1)
plt.title("audio wave")
y,x = enumerate(data[1:10])
plt.plot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-6850f7803411> in <module>
#       2 plt.figure(1)
#       3 plt.title("audio wave")
# ----> 4 y,x = enumerate(data[1:10])
#       5 plt.plot(x,y)
#       6 plt.show()
#
# ValueError: too many values to unpack (expected 2)

# %%
udata = npdata.astype(numpy.uint16)

# %%
udata
# Out:
# array([ 1266,   541, 12620, ...,  1086, 13456,   403], dtype=uint16)

# %%
newdata = udata.astype(numpy.int16)

# %%
newdata
# Out:
# array([ 1171,   256, 13288, ..., 13300,   426,  1157], dtype=int16)

# %%
def twos_comp(val, bits):
    """compute the 2's complement of int value val"""
    if (val & (1 << (bits - 1))) != 0: # if sign bit is set e.g., 8bit: 128-255
        val = val - (1 << bits)        # compute negative value
    return val

# %%
twos_arr = []
for i in data:
    twos_arr.append(twos_comp((i,2),16))
# Out:
# --------------------------------------------------------------------------
# TypeError                                Traceback (most recent call last)
# <ipython-input-18-9b5a849c98ec> in <module>
#       1 twos_arr = []
#       2 for i in data:
# ----> 3     twos_arr.append(twos_comp((i,2),16))
#
# <ipython-input-11-c9ef0a5953d5> in twos_comp(val, bits)
#       1 def twos_comp(val, bits):
#       2     """compute the 2's complement of int value val"""
# ----> 3     if (val & (1 << (bits - 1))) != 0: # if sign bit is set e.g., 8bit: 128-255
#       4         val = val - (1 << bits)        # compute negative value
#       5     return val
#
# TypeError: unsupported operand type(s) for &: 'tuple' and 'int'

# %%
for i in twos_arr:
    print(i)
